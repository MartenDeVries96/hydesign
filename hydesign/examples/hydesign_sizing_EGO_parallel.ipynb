# %% [markdown]
# # Size a HPP using EGO parallel

# %% [markdown]
# This **static** notebook illustrates how to solve hybrid power plant sizing optimization in a specific location based on preselected turbine type.
#
# **To execute this setup a server is required as it relies on parallel evaluation of the model.**
#
# Sizing a hybrid power plant consists on designing the following parameters:
#
# ### Design Variables
#
# **Wind Plant design:**
#
# - Number of wind turbines in the wind plant [-] (`Nwt`)
# - Wind power installation density [MW/km2] (`wind_MW_per_km2`): This parameter controls how closely spaced are the turbines, which in turns affect how much wake losses are present.
#
# **PV Plant design:**
#
# - Solar plant power capacity [MW] (`solar_MW`)
#
# **Battery Storage design:**
#
# - Battery power [MW] (`b_P`)
# - Battery energy capacity in hours [MWh] (`b_E_h `): Battery storage capacity in hours of full battery power (`b_E = b_E_h * b_P `).
# - Cost of battery power fluctuations in peak price ratio [-] (`cost_of_batt_degr`): This parameter controls how much penalty is given to do ramps in battery power in the HPP operation.
#
#
# ### Possible objective functions
#
# - LCOE: Levelized cost of energy.
# - IRR: Internal rate of return. It is not defined for projects that produce negative Net present values. Hydesigb returns IRR = 0 if the NPV < 0. Nevertheless, optimizations can be problematic for sites without a clear case.
# - NPV/CAPEX: Net present value over total CAPEX. A good proxy variable, that will produce optimal sites with the optimal IRR, but that is defined on sites with negative NPV.
#
# The available variables for optimiaztion are:
#
# ```
#  'NPV_over_CAPEX',
#  'NPV [MEuro]',
#  'IRR',
#  'LCOE [Euro/MWh]',
#  'CAPEX [MEuro]',
#  'OPEX [MEuro]',
#  'penalty lifetime [MEuro]',
#  ```

# %%
# Install hydesign if needed
import importlib
if not importlib.util.find_spec("hydesign"):
    # !pip install git+https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git

# %% [markdown]
# ### Example sites

# %%
import pandas as pd
from hydesign.examples import examples_filepath
examples_sites = pd.read_csv(f'{examples_filepath}examples_sites.csv', index_col=0)
examples_sites
# Out:
#       case                            name  longitude   latitude    altitude  \
# 0    India           Indian_site_good_wind  77.500226   8.334294  679.803454
# 1    India          Indian_site_good_solar  68.542204  23.542099   29.883557
# 2    India  Indian_site_bad_solar_bad_wind  77.916878  17.292316  627.424643
# 3   Europe               France_good_solar   4.229736  44.422011  204.000000
# 4   Europe                France_good_wind  -0.864258  48.744116  302.000000
# 5   Europe         France_bad_solar_n_wind   2.167969  47.428087  140.000000
# 6   Europe        Germany_bad_solar_n_wind  10.766602  49.310798  442.000000
# 7   Europe               Germany_good_wind   7.873535  53.287111    5.000000
# 8   Europe              Denmark_good_solar  11.813965  55.397760   42.000000
# 9   Europe               Denmark_good_wind   8.594398  56.227322   85.000000
# 10  Europe                     Netherlands   6.833000  53.450000    2.000000
#
#                                           input_ts_fn          sim_pars_fn  \
# 0            India/input_ts_Indian_site_good_wind.csv   India/hpp_pars.yml
# 1           India/input_ts_Indian_site_good_solar.csv   India/hpp_pars.yml
# 2   India/input_ts_Indian_site_bad_solar_bad_wind.csv   India/hpp_pars.yml
# 3               Europe/input_ts_France_good_solar.csv  Europe/hpp_pars.yml
# 4                Europe/input_ts_France_good_wind.csv  Europe/hpp_pars.yml
# 5         Europe/input_ts_France_bad_solar_n_wind.csv  Europe/hpp_pars.yml
# 6        Europe/input_ts_Germany_bad_solar_n_wind.csv  Europe/hpp_pars.yml
# 7               Europe/input_ts_Germany_good_wind.csv  Europe/hpp_pars.yml
# 8              Europe/input_ts_Denmark_good_solar.csv  Europe/hpp_pars.yml
# 9               Europe/input_ts_Denmark_good_wind.csv  Europe/hpp_pars.yml
# 10                    Europe/input_ts_Netherlands.csv  Europe/hpp_pars.yml
#
#                          price_fn price_col
# 0   India/Indian_elec_price_t.csv     Price
# 1   India/Indian_elec_price_t.csv     Price
# 2   India/Indian_elec_price_t.csv     Price
# 3        Europe/2030-EL_PRICE.csv      FR_R
# 4        Europe/2030-EL_PRICE.csv      FR_R
# 5        Europe/2030-EL_PRICE.csv      FR_R
# 6        Europe/2030-EL_PRICE.csv     DE_ME
# 7        Europe/2030-EL_PRICE.csv     DE_NW
# 8        Europe/2030-EL_PRICE.csv      DK_E
# 9        Europe/2030-EL_PRICE.csv      DK_W
# 10       Europe/2030-EL_PRICE.csv      NL_R

# %% [markdown]
# ### Running Parallel EGO

# %%
from hydesign.Parallel_EGO import EfficientGlobalOptimizationDriver, get_kwargs
from smt.applications.mixed_integer import (
    MixedIntegerContext,
    FLOAT,
    INT,)
import numpy as np
from hydesign.hpp_assembly import hpp_model

# %%
inputs = {
    'example': 9,
    'name': None,
    'longitude': None,
    'latitude': None,
    'altitude': None,
    'input_ts_fn': None,
    'sim_pars_fn': None,

    'opt_var': "NPV_over_CAPEX",
    'rotor_diameter_m': 100,
    'hub_height_m': 120,
    'wt_rated_power_MW': 2,
    'surface_tilt_deg': 20,
    'surface_azimuth_deg': 180,
    'DC_AC_ratio': 1,
    'num_batteries': 2,
    'n_procs': 31,
    'n_doe': 128,
    'n_clusters': 4,
    'n_seed': 0,
    'max_iter': 15,
    'final_design_fn': 'hydesign_output_9.csv',
    'npred': 2e4, #1e5, #3e4, 2e4
    'tol': 1e-6,
    'min_conv_iter': 3,
    'work_dir': './',
    }

kwargs = get_kwargs(inputs)
     
kwargs['variables'] = {
    'clearance [m]':
        {'var_type':'design',
         'limits':[10, 60],
         'types':INT
         },
     'sp [m2/W]':
        {'var_type':'design',
         'limits':[200, 360],
         'types':INT
         },
    'p_rated [MW]':
        {'var_type':'design',
         'limits':[1, 10],
         'types':INT
         },
    'Nwt':
        {'var_type':'design',
         'limits':[0, 400],
         'types':INT
         },
    'wind_MW_per_km2 [MW/km2]':
        {'var_type':'design',
         'limits':[5, 9],
         'types':FLOAT
         },
    'solar_MW [MW]':
        {'var_type':'design',
         'limits':[0, 400],
         'types':INT
         },
    'surface_tilt [deg]':
        {'var_type':'design',
         'limits':[0, 50],
         'types':FLOAT
         },
    'surface_azimuth [deg]':
        {'var_type':'design',
         'limits':[150, 210],
         'types':FLOAT
         },
    'DC_AC_ratio':
        {'var_type':'design',
         'limits':[1, 2.0],
         'types':FLOAT
         },
    # 'DC_AC_ratio':
    #     {'var_type':'fixed',
    #      'value':1.0,
    #      },
    'b_P [MW]':
        {'var_type':'design',
         'limits':[0, 10],
         'types':INT
         },
    'b_E_h [h]':
        {'var_type':'design',
         'limits':[1, 10],
         'types':INT
         },
    'cost_of_battery_P_fluct_in_peak_price_ratio':
        {'var_type':'design',
         'limits':[0, 20],
         'types':FLOAT
         },
} 

EGOD = EfficientGlobalOptimizationDriver(model=hpp_model, **kwargs)
EGOD.run()
result = EGOD.result
# Out:
# Selected example site:
# ---------------------------------------------------
# case                                          Europe
# name                               Denmark_good_wind
# longitude                                   8.594398
# latitude                                   56.227322
# altitude                                        85.0
# input_ts_fn    Europe/input_ts_Denmark_good_wind.csv
# sim_pars_fn                      Europe/hpp_pars.yml
# price_fn                    Europe/2030-EL_PRICE.csv
# price_col                                       DK_W
# Name: 9, dtype: object
#
#
#
#
# Sizing a HPP plant at Denmark_good_wind:
#
#
# Fixed parameters on the site
# -------------------------------
# longitude = 8.594398
# latitude = 56.227322
# altitude = 85.0
#
#
#
# Initial 128 simulations took 1.27 minutes
#   Current solution -NPV_over_CAPEX = -3.586E-01
#
# Update sm and extract candidate points took 0.08 minutes
# Check-optimal candidates: new 28 simulations took 0.26 minutes
#   Current solution -NPV_over_CAPEX = -3.833E-01
#   rel_yopt_change = -6.43E-02
# Iteration 1 took 0.39 minutes
#
# Update sm and extract candidate points took 0.09 minutes
# Check-optimal candidates: new 27 simulations took 0.26 minutes
#   Current solution -NPV_over_CAPEX = -4.166E-01
#   rel_yopt_change = -8.00E-02
# Iteration 2 took 0.42 minutes
#
# Update sm and extract candidate points took 0.09 minutes
# Check-optimal candidates: new 28 simulations took 0.26 minutes
#   Current solution -NPV_over_CAPEX = -4.232E-01
#   rel_yopt_change = -1.54E-02
# Iteration 3 took 0.43 minutes
#
# Update sm and extract candidate points took 0.1 minutes
# Check-optimal candidates: new 27 simulations took 0.26 minutes
#   Current solution -NPV_over_CAPEX = -4.275E-01
#   rel_yopt_change = -1.01E-02
# Iteration 4 took 0.45 minutes
#
# Update sm and extract candidate points took 0.1 minutes
# Check-optimal candidates: new 26 simulations took 0.26 minutes
#   Current solution -NPV_over_CAPEX = -4.282E-01
#   rel_yopt_change = -1.64E-03
# Iteration 5 took 0.46 minutes
#
# Update sm and extract candidate points took 0.1 minutes
# Check-optimal candidates: new 25 simulations took 0.24 minutes
#   Current solution -NPV_over_CAPEX = -4.285E-01
#   rel_yopt_change = -7.81E-04
# Iteration 6 took 0.48 minutes
#
# Update sm and extract candidate points took 0.11 minutes
# Check-optimal candidates: new 24 simulations took 0.25 minutes
#   Current solution -NPV_over_CAPEX = -4.285E-01
#   rel_yopt_change = -0.00E+00
# Iteration 7 took 0.52 minutes
#
# Update sm and extract candidate points took 0.11 minutes
# Check-optimal candidates: new 21 simulations took 0.25 minutes
#   Current solution -NPV_over_CAPEX = -4.292E-01
#   rel_yopt_change = -1.55E-03
# Iteration 8 took 0.56 minutes
#
# Update sm and extract candidate points took 0.11 minutes
# Check-optimal candidates: new 23 simulations took 0.25 minutes
#   Current solution -NPV_over_CAPEX = -4.292E-01
#   rel_yopt_change = -0.00E+00
# Iteration 9 took 0.57 minutes
#
# Update sm and extract candidate points took 0.11 minutes
# Check-optimal candidates: new 20 simulations took 0.25 minutes
#   Current solution -NPV_over_CAPEX = -4.292E-01
#   rel_yopt_change = -0.00E+00
# Iteration 10 took 0.61 minutes
#
# Update sm and extract candidate points took 0.11 minutes
# Check-optimal candidates: new 19 simulations took 0.24 minutes
#   Current solution -NPV_over_CAPEX = -4.292E-01
#   rel_yopt_change = -0.00E+00
# Iteration 11 took 0.63 minutes
#
# Surrogate based optimization is converged.
#
# Design:
# ---------------
# clearance [m]: 10.000
# sp [m2/W]: 342.000
# p_rated [MW]: 4.000
# Nwt: 77.000
# wind_MW_per_km2 [MW/km2]: 5.000
# solar_MW [MW]: 0.000
# surface_tilt [deg]: 0.000
# surface_azimuth [deg]: 150.000
# DC_AC_ratio: 1.000
# b_P [MW]: 0.000
# b_E_h [h]: 1.000
# cost_of_battery_P_fluct_in_peak_price_ratio: 1.129
#
#
# NPV_over_CAPEX: 0.429
# NPV [MEuro]: 129.932
# IRR: 0.094
# LCOE [Euro/MWh]: 21.954
# CAPEX [MEuro]: 302.744
# OPEX [MEuro]: 6.077
# Wind CAPEX [MEuro]: 233.282
# Wind OPEX [MEuro]: 6.077
# PV CAPEX [MEuro]: 0.000
# PV OPEX [MEuro]: 0.000
# Batt CAPEX [MEuro]: 0.000
# Batt OPEX [MEuro]: 0.000
# Shared CAPEX [MEuro]: 69.462
# Shared Opex [MEuro]: 0.000
# penalty lifetime [MEuro]: 0.000
# AEP [GWh]: 1292.614
# GUF: 0.492
# grid [MW]: 300.000
# wind [MW]: 308.000
# solar [MW]: 0.000
# Battery Energy [MWh]: 0.000
# Battery Power [MW]: 0.000
# Total curtailment [GWh]: 189.072
# Awpp [km2]: 61.600
# Rotor diam [m]: 122.032
# Hub height [m]: 71.016
# Number_of_batteries: 2.000
#
# Optimization with 11 iterations and 379 model evaluations took 6.86 minutes
